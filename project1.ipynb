# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("fifa_eda.csv")

# %%
df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
df.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     17955 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Position                  18207 non-null  object
# ...

# %%
df.shape
# Out:
# (18207, 18)

# %%
df.isnull().sum()
# Out:
# ID                            0
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                        241
# Value                       252
# Wage                          0
# Preferred Foot                0
# International Reputation     48
# Skill Moves                  48
# Position                      0
# Joined                        0
# Contract Valid Until        289
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
df.fillna({'Club':"Not specified","Contract Valid Until":"Not specified","International Reputation":"Not specified","Skill Moves":"Not Specified "},inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                            0
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                          0
# Value                       252
# Wage                          0
# Preferred Foot                0
# International Reputation      0
# Skill Moves                   0
# Position                      0
# Joined                        0
# Contract Valid Until          0
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
df.tail()
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot International Reputation  \
# 18202   Crewe Alexandra   60.0   1.0          Right                      1.0
# 18203    Trelleborgs FF   60.0   1.0          Right                      1.0
# 18204  Cambridge United   60.0   1.0          Right                      1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                      1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                      1.0
#
# ...

# %%
df.shape
# Out:
# (18207, 18)

# %%
df['Position'].value_counts()
# Out:
# Position
# ST     2154
# GK     2027
# CB     1779
# CM     1395
# LB     1372
# RB     1291
# RM     1127
# LM     1095
# CAM     959
# CDM     948
# RCB     662
# LCB     648
# LCM     395
# RCM     391
# LW      381
# RW      370
# RDM     248
# LDM     243
# LS      207
# RS      203
# RWB      87
# LWB      78
# CF       74
# LAM      21
# RAM      21
# RF       16
# LF       15
# Name: count, dtype: int64

# %%
top_10= df.groupby('Nationality')['Wage'].agg(['sum']).sort_values(by='sum', ascending=False)
top_10_wage=top_10.head(10)
top_10_wage
# Out:
#                  sum
# Nationality
# Spain        17498.0
# England      16526.0
# Brazil       14703.0
# France       12845.0
# Germany      11548.0
# Argentina    10778.0
# Italy         9462.0
# Belgium       4805.0
# Portugal      4608.0
# Netherlands   4546.0

# %% [markdown]
# Distribution of Players’ Overall Ratings

# %%
plt.Figure(figsize=(8,5))
sns.histplot(data=df,x='Overall')
plt.xlabel('Overall Rting')
plt.ylabel('Number of players')
plt.show()

# %% [markdown]
# Age of the players

# %%
plt.Figure(figsize=(8,5))
print(df['Age'].median())
sns.histplot(x='Age',data=df)
plt.xlabel("Age")
plt.ylabel("Number of players")
plt.show()
# Out:
# 25.0

# %% [markdown]
# Top 10 Nationalities by Player Count

# %%
plt.figure(figsize=(8,5))
top10=df["Nationality"].value_counts().head(10)
data = top10.reset_index()
data.columns=['Nationality','Player Count']
sns.barplot(x="Nationality",y="Player Count",data=data,color='Orange',edgecolor='black')
plt.title("Top 10 Nationalities by Player Count")
plt.xlabel('Nationality')
plt.ylabel("Number of players")
plt.show()

# %% [markdown]
# Age vs Overall Rating

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['Age'],df['Overall'],color='orange')
plt.xlabel('Age')
plt.ylabel("Overall Ratin")
plt.title("Age vs Overall Rating")
plt.show()

# %% [markdown]
# Strong Foot

# %%
plt.figure(figsize=(8,5))
colors=['red','orange']
sns.countplot(data=df,x='Preferred Foot',hue="Preferred Foot",palette=colors)
plt.show()

# %% [markdown]
# Top 10 Clubs by Average Overall Rating

# %%
plt.figure(figsize=(8,5))
topclubs= df.groupby('Club')['Overall'].mean().sort_values(ascending=False).head(10)
topclubs.plot(kind='barh', color='green')
plt.title('Top 10 Clubs by Avg Overall Rating')
plt.xlabel('Average Overall Rating')
# Out:
# Text(0.5, 0, 'Average Overall Rating')

# %% [markdown]
# Age for Top 10 Nationalities

# %%
top10=df['Nationality'].value_counts().head(10).index
topnations = df[df['Nationality'].isin(top10)]
plt.figure(figsize=(12,6))
sns.boxplot(data=topnations, x='Nationality', y='Age',hue="Nationality",palette='Set3')
plt.title('Age for Top 10 Nationalities')
plt.xticks(rotation=45)
plt.xlabel('Nationality')
plt.ylabel('Age')
plt.show()

# %%
corr=df.corr(numeric_only=True)
numeric_cols= df.corr(numeric_only=True)
sns.heatmap(corr, annot=True,cmap="coolwarm",fmt=".2f")
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     17955 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Position                  18207 non-null  object
# ...

# %%
sns.lineplot(data=df,x='Age',y='Wage')
# Out:
# <Axes: xlabel='Age', ylabel='Wage'>
